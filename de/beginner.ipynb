# %% [markdown]
# ##### Copyright 2019 Die TensorFlow-Autoren.

# %%
#@title Licensed under the Apache License, Version 2.0 (the "License");
# you may not use this file except in compliance with the License.
# You may obtain a copy of the License at
#
# https://www.apache.org/licenses/LICENSE-2.0
#
# Unless required by applicable law or agreed to in writing, software
# distributed under the License is distributed on an "AS IS" BASIS,
# WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# See the License for the specific language governing permissions and
# limitations under the License.

# %% [markdown]
# # Beginnen Sie mit TensorFlow 2.0 für Anfänger

# %% [markdown]
# Note: Вся информация в этом разделе переведена с помощью русскоговорящего Tensorflow сообщества на общественных началах. Поскольку этот перевод не является официальным, мы не гарантируем что он на 100% аккуратен и соответствует [официальной документации на английском языке](https://www.tensorflow.org/?hl=en). Если у вас есть предложение как исправить этот перевод, мы будем очень рады увидеть pull request в [tensorflow/docs](https://github.com/tensorflow/docs) репозиторий GitHub. Если вы хотите помочь сделать документацию по Tensorflow лучше (сделать сам перевод или проверить перевод подготовленный кем-то другим), напишите нам на [docs-ru@tensorflow.org list](https://groups.google.com/a/tensorflow.org/forum/#!forum/docs-ru).

# %% [markdown]
# Tri na Tri

# %% [markdown]
# Dies ist die [Google Colaboratory-](https://colab.research.google.com/notebooks/welcome.ipynb) Notizbuchdatei. Python-Programme, die direkt im Browser ausgeführt werden, sind eine gute Möglichkeit, TensorFlow zu erlernen und zu verwenden. Um diesem Handbuch zu folgen, starten Sie das Notizbuch in Google Colab, indem Sie oben auf dieser Seite auf die entsprechende Schaltfläche klicken.
#
# 1. Stellen Sie in Colab eine Verbindung zur Python-Laufzeit her: Wählen Sie in der oberen rechten Ecke der Menüleiste die *Option VERBINDEN* .
# 2. Führen Sie den Code in allen Notebook-Zellen aus: Wählen Sie *Runtime* und *Run All* .

# %% [markdown]
# Dies ist eine Datei.
#
# 1. Einzelne Datei.
# 2. Zweite Datei

# %% [markdown]
# Guten Abend ist heute angekommen! Überprüfen Sie diese [Google-Kollaborationsdatei](https://google.com)

# %% [markdown]
# Laden Sie das TensorFlow 2.0 Beta-Paket herunter und installieren Sie es. Importieren Sie in Ihr TensorFlow-Programm:

# %%
# Install TensorFlow

import tensorflow as tf

# %% [markdown]
# Загрузите и установите [набор данных MNIST](http://yann.lecun.com/exdb/mnist/). Преобразуйте примеры из целых чисел в числа с плавающей запятой:

# %%
mnist = tf.keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# %% [markdown]
# Создайте модель `tf.keras.Sequential`, сложив слои. Выберите оптимизатор и функцию потерь для обучения:

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# Trainieren und bewerten Sie das Modell:

# %%
model.fit(x_train, y_train, epochs=5)

model.evaluate(x_test,  y_test, verbose=2)

# %% [markdown]
# Классификатор изображений теперь обучен на этих данных с точностью ~ 98%. Чтобы узнать больше, прочитайте [учебники по TensorFlow](https://www.tensorflow.org/tutorials/).
